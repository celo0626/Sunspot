# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_forecast = pd.read_csv('ForecastSunspotResults.csv')
df_forecast['Date'] = pd.to_datetime(df_forecast[['Year', 'Month', 'Day']])
df_forecast['Date'] = pd.to_datetime(df_forecast['Date'])
last_month = df_forecast['Date'].dt.year.max()
start_month = last_year - 4  # Son 5 yılı kapsayacak şekilde başlangıç yılı

df_last_5_years = df_forecast[df_forecast['Date'].dt.month >= start_month].copy()


sns.lineplot(data=df_last_5_years, x='Date', y='Monthly Mean Total Sunspot Number', label='Monthly Mean Total Sunspot Number')

# Sunspot forecast
sns.lineplot(data=df_last_5_years, x='Date', y='Forecast_Sunspot', label='Sunspot Forecast')

# Grafik başlık ve eksen ayarları
plt.title(f'Son 5 Yıl İçin Aylık Güneş Lekesi Sayısı ve Tahmini ({start_year}-{last_year})', fontsize=14)
plt.xlabel('Tarih', fontsize=12)
plt.ylabel('Güneş Lekesi Sayısı', fontsize=12)
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
