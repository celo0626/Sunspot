# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Sunspots.csv")
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df.drop(index=df[df["Monthly Mean Total Sunspot Number"] == 0].index,inplace=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# %%
df = df[~df['Year'].between(1790, 1830)]
df = df.reset_index(drop=True)

# %%
df['Month_sin'] = np.sin(2 * np.pi * df['Month'] / 12)
df['Month_cos'] = np.cos(2 * np.pi * df['Month'] / 12)
df['Year_sin'] = np.sin(2 * np.pi * (df['Year'] - df['Year'].min()) / 11)
df['Year_cos'] = np.cos(2 * np.pi * (df['Year'] - df['Year'].min()) / 11)
df['Sunspot_lag1'] = df['Monthly Mean Total Sunspot Number'].shift(1)
df['Sunspot_Lag_12'] = df['Monthly Mean Total Sunspot Number'].shift(12)
df['Diff_11Year'] = df['Monthly Mean Total Sunspot Number'].diff(periods=132)

df.dropna(inplace=True)

# %%
df.to_csv("ForecastSunspot.csv", index=False)

# %%
df
# Out:
#            Date  Monthly Mean Total Sunspot Number  Year  Month  Day  \
# 132  1760-04-30                               97.2  1760      4   30
# 133  1760-05-31                              120.0  1760      5   31
# 134  1760-06-30                               80.5  1760      6   30
# 135  1760-07-31                              110.0  1760      7   31
# 136  1760-08-31                              126.0  1760      8   31
# ...         ...                                ...   ...    ...  ...
# 2751 2020-09-30                                0.6  2020      9   30
# 2752 2020-10-31                               14.4  2020     10   31
# 2753 2020-11-30                               34.0  2020     11   30
# 2754 2020-12-31                               21.8  2020     12   31
# 2755 2021-01-31                               10.4  2021      1   31
#
#          Month_sin     Month_cos      Year_sin  Year_cos  Sunspot_lag1  \
# 132   8.660254e-01 -5.000000e-01 -1.133108e-15  1.000000         124.5
# 133   5.000000e-01 -8.660254e-01 -1.133108e-15  1.000000          97.2
# 134   1.224647e-16 -1.000000e+00 -1.133108e-15  1.000000         120.0
# 135  -5.000000e-01 -8.660254e-01 -1.133108e-15  1.000000          80.5
# 136  -8.660254e-01 -5.000000e-01 -1.133108e-15  1.000000         110.0
# ...            ...           ...           ...       ...           ...
# 2751 -1.000000e+00 -1.836970e-16 -7.557496e-01 -0.654861           7.5
# 2752 -8.660254e-01  5.000000e-01 -7.557496e-01 -0.654861           0.6
# 2753 -5.000000e-01  8.660254e-01 -7.557496e-01 -0.654861          14.4
# 2754 -2.449294e-16  1.000000e+00 -7.557496e-01 -0.654861          34.0
# 2755  5.000000e-01  8.660254e-01 -9.898214e-01 -0.142315          21.8
#
#       Sunspot_Lag_12  Diff_11Year
# 132             78.3          0.5
# 133             81.7         15.7
# 134             83.3        -36.2
# 135             85.0         17.2
# 136            118.8        -15.7
# ...              ...          ...
# 2751             1.1         -6.5
# 2752             0.4          6.7
# 2753             0.5         27.1
# 2754             1.5          5.5
# 2755             6.2         -9.1
#
# [2624 rows x 12 columns]
