# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Sunspots.csv')


df.columns = [ 'Index','Date', 'Sunspot']


df['Date'] = pd.to_datetime(df['Date'])
df.drop(index=df[df["Sunspot"] == 0].index,inplace=True)


df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df = df[~df['Year'].between(1790, 1830)]
df = df.reset_index(drop=True)
annual_df = df.groupby('Year')['Sunspot'].mean().reset_index()

# %%
df['RollMean_11year'] = df['Sunspot'].rolling(window=132).mean()
df['RollStd_11year'] = df['Sunspot'].rolling(window=132).std()
#df['RollMax_11year'] = df['Sunspot'].rolling(window=132).max()
#df['RollMin_11year'] = df['Sunspot'].rolling(window=132).min()

# %%
df['Diff_11Year'] = df['Sunspot'].diff(periods=132)
df['Sunspot_lag1'] = df['Sunspot'].shift(1)
df['Sunspot_lag132'] = df['Sunspot'].shift(132)

# %%
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df.tail(20)
# Out:
#       Index       Date  Sunspot  Year  Month  Day  RollMean_11year  \
# 2604   3245 2019-06-30      1.2  2019      6   30        49.574242
# 2605   3246 2019-07-31      0.9  2019      7   31        49.541667
# 2606   3247 2019-08-31      0.5  2019      8   31        49.540909
# 2607   3248 2019-09-30      1.1  2019      9   30        49.546970
# 2608   3249 2019-10-31      0.4  2019     10   31        49.540909
# 2609   3250 2019-11-30      0.5  2019     11   30        49.512879
# 2610   3251 2019-12-31      1.5  2019     12   31        49.474242
# 2611   3252 2020-01-31      6.2  2020      1   31        49.513636
# 2612   3253 2020-02-29      0.2  2020      2   29        49.505303
# 2613   3254 2020-03-31      1.5  2020      3   31        49.507576
# 2614   3255 2020-04-30      5.2  2020      4   30        49.542424
# 2615   3256 2020-05-31      0.2  2020      5   31        49.534848
# 2616   3257 2020-06-30      5.8  2020      6   30        49.556818
# 2617   3258 2020-07-31      6.1  2020      7   31        49.555303
# 2618   3259 2020-08-31      7.5  2020      8   31        49.570455
# 2619   3260 2020-09-30      0.6  2020      9   30        49.521212
# 2620   3261 2020-10-31     14.4  2020     10   31        49.571970
# 2621   3262 2020-11-30     34.0  2020     11   30        49.777273
# 2622   3263 2020-12-31     21.8  2020     12   31        49.818939
# 2623   3264 2021-01-31     10.4  2021      1   31        49.750000
#
#       RollStd_11year  Diff_11Year  Sunspot_lag1  Sunspot_lag132
# 2604       41.213219         -3.4           9.9             4.6
# 2605       41.250244         -4.3           1.2             5.2
# 2606       41.251150         -0.1           0.9             0.6
# 2607       41.243919          0.8           0.5             0.3
# 2608       41.251135         -0.8           1.1             1.2
# 2609       41.283424         -3.7           0.4             4.2
# 2610       41.326257         -5.1           0.5             6.6
# 2611       41.282151          5.2           1.5             1.0
# 2612       41.292068         -1.1           6.2             1.3
# 2613       41.289397          0.3           0.2             1.2
# 2614       41.249726          4.6           1.5             0.6
# 2615       41.258763         -1.0           5.2             1.2
# 2616       41.234506          2.9           0.2             2.9
# 2617       41.236111         -0.2           5.8             6.3
# 2618       41.220164          2.0           6.1             5.5
# 2619       41.275134         -6.5           7.5             7.1
# 2620       41.227404          6.7           0.6             7.7
# 2621       41.080499         27.1          14.4             6.9
# 2622       41.049062          5.5          34.0            16.3
# 2623       41.107969         -9.1          21.8            19.5
