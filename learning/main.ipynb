# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np



df = pd.read_csv("matches_full.csv")

# %%
df.tail()
# Out:
#       Unnamed: 0        date   time     comp         round  day venue result  \
# 4313          48  2020-07-05  17:00  La Liga  Matchweek 34  Sun  Home      L
# 4314          49  2020-07-08  22:00  La Liga  Matchweek 35  Wed  Away      L
# 4315          50  2020-07-12  14:00  La Liga  Matchweek 36  Sun  Home      L
# 4316          51  2020-07-16  21:00  La Liga  Matchweek 37  Thu  Away      L
# 4317          52  2020-07-19  21:00  La Liga  Matchweek 38  Sun  Home      D
#
#        gf   ga  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 4313  0.0  1.0  ...  Match Report    NaN   7.0  2.0  18.9  1.0  0     0
# 4314  0.0  1.0  ...  Match Report    NaN  11.0  2.0  18.1  1.0  0     0
# 4315  0.0  2.0  ...  Match Report    NaN  14.0  3.0  20.8  3.0  0     0
# 4316  0.0  1.0  ...  Match Report    NaN  18.0  6.0  21.3  3.0  0     0
# 4317  0.0  0.0  ...  Match Report    NaN   8.0  1.0  17.2  0.0  0     0
#
#      season      team
# 4313   2020  Espanyol
# 4314   2020  Espanyol
# ...

# %%
pip install tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\python.exe: No module named pip
